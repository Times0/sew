# %%
# !pip install ultralytics
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Z4mFtu232oWID8Vtcntw")
project = rf.workspace("testsew").project("box-counting-dqcyf")
version = project.version(4)
dataset = version.download("yolov8")

# %%
import os

cwd = os.getcwd()
path = "Box-Counting-4"
path = os.path.join(cwd, path)
print(path)
# Out:
# /home/nicolastovantrang/Desktop/sew-1/Box-Counting-4

# %%
# !yolo mode=train model=yolov8x.pt data={path}/data.yaml epochs=100 imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24195MiB)
# ...
